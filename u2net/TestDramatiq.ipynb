# %%
from processimage import process_image

# %%
from PIL import Image
import base64
import json
from io import BytesIO

# %%
def pil_to_b64(im, enc_format="png", **kwargs):
    buff = BytesIO()
    im.save(buff, format=enc_format, **kwargs)
    return base64.b64encode(buff.getvalue()).decode("utf-8")

# %%
def b64_to_pil(string):
    decoded = base64.b64decode(string)
    buffer = BytesIO(decoded)
    im = Image.open(buffer)

    return im

# %%
im = Image.open("/Users/jantkacik/Downloads/resized-pngs/HACKATON-images-unann-resized/iz190929_2C06.png")

# %%
im
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1024x768 at 0x11855EE80>

# %%
result = process_image.send(pil_to_b64(im))

# %% [markdown]
# result

# %%
result.message_id
# Out:
# 'dbdb694b-03a3-4d65-bbcd-d0e675e18d09'

# %%
b64_to_pil(json.loads(result.get_result())["mask"])
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=L size=512x384 at 0x12CB918D0>
